# %%
from xarm.wrapper import XArmAPI

ROBOT_IP = "192.168.1.161"
arm = XArmAPI(ROBOT_IP)
# Out:
# ROBOT_IP: 192.168.1.161, VERSION: v1.11.4, PROTOCOL: V1, DETAIL: 6,9,LI1003,DL1000,v1.11.4, TYPE1300: [0, 0]
# change protocol identifier to 3
# ControllerError, code: 2

# %%
from applied_planning.hardware import XArmLite6Adapter  
robot = XArmLite6Adapter(ROBOT_IP)

robot.reset() # move robot to home position
# Out:
# Connecting to Lite6 at 192.168.1.161...
# ROBOT_IP: 192.168.1.161, VERSION: v1.11.4, PROTOCOL: V1, DETAIL: 6,9,LI1003,DL1000,v1.11.4, TYPE1300: [0, 0]
# change protocol identifier to 3
# ControllerError, code: 2
# [motion_enable], xArm is not ready to move
# [set_state], xArm is ready to move
# ✓ Connected to Lite6
#   Version: 6,9,LI1003,DL1000,v1.11.4
#   State: 0
# Moving to home position...
# ControllerError had clean
# ControllerError had clean
# ✓ Home position reached
# {'qpos': array([ 0.00622   ,  0.01394   ,  1.56800101, -0.275539  ,  1.56266301,
#          0.00901201]),
#  'qvel': array([0., 0., 0., 0., 0., 0.])}

# %%
import time
import math
import numpy as np

print("Generating smooth circular trajectory with sine wave...")

radius = 0.15
center_x = 0.3
center_y = 0.0
base_z = 0.2
z_amplitude = 0.05
num_points = 100
total_time = 30  # seconds

trajectory = []
for i in range(num_points):
    angle = 2 * math.pi * i / num_points
    z_angle = 4 * math.pi * i / num_points
    
    x = (center_x + radius * math.cos(angle)) * 1000  # mm
    y = (center_y + radius * math.sin(angle)) * 1000  # mm
    z = (base_z + z_amplitude * math.sin(z_angle)) * 1000  # mm
    
    trajectory.append([x, y, z, 180, 0, 0])  # [x, y, z, roll, pitch, yaw]

print(f"Generated {len(trajectory)} waypoints")
print(f"First point: {trajectory[0][:3]}")
print(f"Last point: {trajectory[-1][:3]}")

try:
    robot.arm.set_mode(0)
    robot.arm.set_state(0)
    
    for i, point in enumerate(trajectory):
        robot.arm.set_position(
            x=point[0], y=point[1], z=point[2],
            roll=point[3], pitch=point[4], yaw=point[5],
            speed=100,
            wait=False  
        )
        
        if i % 10 == 0:
            print(f"Waypoint {i}/{len(trajectory)}")
        
        time.sleep(total_time / num_points)
    
    print("✓ Trajectory complete!")
    
except KeyboardInterrupt:
    print("\nStopped by user")
    robot.arm.set_state(4)
# Out:
# Generating smooth circular trajectory with sine wave...
# Generated 100 waypoints
# First point: [449.99999999999994, 0.0, 200.0]
# Last point: [449.7040092642407, -9.418577929396989, 193.7333383217848]
# Waypoint 0/100
# Waypoint 10/100
# ControllerError, code: 21ControllerError, code: 21
#
# ControllerError, code: 21
# [SDK][ERROR][2025-11-02 21:51:01][base.py:383] - - API -> set_position -> code=1, pos=[409.34529411321176, 102.68206588930329, 249.9013364214136, 3.141592653589793, 0.0, 0.0], radius=-1, velo=100.0, acc=2000
# [SDK][ERROR][2025-11-02 21:51:01][base.py:383] - - API -> set_position -> code=1, pos=[402.68206588930326, 109.34529411321172, 249.9013364214136, 3.141592653589793, 0.0, 0.0], radius=-1, velo=100.0, acc=2000
# [SDK][ERROR][2025-11-02 21:51:01][base.py:383] - - API -> set_position -> code=1, pos=[395.6135984623034, 115.57698641636837, 249.11436253643447, 3.141592653589793, 0.0, 0.0], radius=-1, velo=100.0, acc=2000
# ...
