# %%
# Real hardware - just swap the adapter!
from applied_planning.hardware import XArmLite6Adapter  
robot = XArmLite6Adapter(robot_ip='192.168.1.161')

# Same control code works for both
robot.reset()
robot.step({'qvel': [0.1, 0, 0, 0, 0, 0]})
robot.reset()
robot.step({'qvel': [0, 0.1, 0.1, 0, 0, 0]})
# Out:
# Connecting to Lite6 at 192.168.1.161...
# [SDK][ERROR][2025-11-01 17:37:04][base.py:293] - - [main-socket] recv error: [Errno 54] Connection reset by peer
# [SDK][ERROR][2025-11-01 17:37:06][decorator.py:39] - - xArm is not connected
# [SDK][ERROR][2025-11-01 17:37:06][decorator.py:39] - - xArm is not connected
# [SDK][ERROR][2025-11-01 17:37:06][decorator.py:39] - - xArm is not connected
# [SDK][ERROR][2025-11-01 17:37:06][decorator.py:39] - - xArm is not connected
# [SDK][ERROR][2025-11-01 17:37:06][decorator.py:39] - - xArm is not connected
# [SDK][ERROR][2025-11-01 17:37:06][decorator.py:39] - - xArm is not connected
# [SDK][ERROR][2025-11-01 17:37:06][decorator.py:39] - - xArm is not connected
# [SDK][ERROR][2025-11-01 17:37:06][decorator.py:39] - - xArm is not connected
# [SDK][ERROR][2025-11-01 17:37:06][decorator.py:39] - - xArm is not connected
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Real hardware - just swap the adapter!
#       2 from applied_planning.hardware import XArmLite6Adapter
# ----> 3 robot = XArmLite6Adapter(robot_ip='192.168.1.161')
#       5 # Same control code works for both
#       6 robot.reset()
#
# File ~/Development/applied-planning/src/applied_planning/hardware/xarm_lite6_adapter.py:40, in XArmLite6Adapter.__init__(self, robot_ip, control_dt, max_velocity, max_acceleration)
#      38 # Connect to robot
#      39 print(f"Connecting to Lite6 at {robot_ip}...")
# ---> 40 self.arm = XArmAPI(robot_ip)
#      42 # Enable motion and set mode
#      43 self.arm.motion_enable(enable=True)
#
# File ~/Development/applied-planning/.venv/lib/python3.10/site-packages/xarm/wrapper/xarm_api.py:85, in XArmAPI.__init__(self, port, is_radian, do_not_open, **kwargs)
#      15 """
#      16 The API wrapper of xArm
#      17 Note: Orientation of attitude angle
#    (...)
#      82         Note: only available if firmware_version < 1.5.20
#      83 """
#      84 self._is_radian = is_radian
# ---> 85 self._arm = XArm(port=port,
#      86                  is_radian=is_radian,
#      87                  do_not_open=do_not_open,
#      88                  instance=self,
#      89                  **kwargs)
#      90 self._studio = Studio(port, True)
#      91 self.__attr_alias_map = {
#      92     'get_ik': self.get_inverse_kinematics,
#      93     'get_fk': self.get_forward_kinematics,
#    (...)
#     132     'set_linear_track_stop': self.set_linear_motor_stop,
#     133 }
#
# File ~/Development/applied-planning/.venv/lib/python3.10/site-packages/xarm/x3/xarm.py:49, in XArm.__init__(self, port, is_radian, do_not_open, instance, **kwargs)
#      47 kwargs['init'] = True
#      48 self._api_instance = instance
# ---> 49 Base.__init__(self, port, is_radian, do_not_open, **kwargs)
#
# File ~/Development/applied-planning/.venv/lib/python3.10/site-packages/xarm/x3/base.py:256, in Base.__init__(self, port, is_radian, do_not_open, **kwargs)
#     253 self._fb_transid_result_map = {}
#     255 if not do_not_open:
# --> 256     self.connect()
#
# File ~/Development/applied-planning/.venv/lib/python3.10/site-packages/xarm/x3/base.py:916, in Base.connect(self, port, baudrate, timeout, axis, arm_type)
#     913 except:
#     914     self._stream_report = None
# --> 916 if self._check_version(is_first=True) < 0:
#     917     self.disconnect()
#     918     raise Exception('failed to check version, close')
#
# File ~/Development/applied-planning/.venv/lib/python3.10/site-packages/xarm/x3/base.py:399, in Base._check_version(self, is_first)
#     397     fail_cnt += 1 if code != 0 else 0
#     398     if code != 0 or not self._version:
# --> 399         time.sleep(0.1)
#     400 if not self._version and fail_cnt >= 100:
#     401     logger.error('failed to get version')
#
# KeyboardInterrupt:
